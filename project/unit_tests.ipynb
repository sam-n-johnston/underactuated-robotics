# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
import unittest
from TestTakeOffPlus import TestTakeOffPlus


 
suite = unittest.TestLoader().loadTestsFromTestCase(TestTakeOffPlus)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_liftoff_minus_state_5 (TestTakeOffPlus.TestTakeOffPlus) ...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <img src="data:image/png;base64,..." width="640">
# touchdown!
# [ 0.64325532  1.47009987 -0.1        -0.1         0.5         1.
#  -6.31033466  0.          0.          0.        ]
# START: -6.310
# -0.20000000000000018
# previous_velocity_along_leg_frame
# 1.5
# LIFTED OFF!
# [ 0.2306371   1.33103777 -0.1        -0.39352708  0.5        -3.73482399
#   5.34725381  0.         -0.50504766  6.47846921]
# 0.47550000000000037
# STARING
# 1313
# 2307
# TRYING1
# (10, 2307)
# (10, 952)
# TRYING2
# (10, 2307)
# (10, 2307)
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# simulated_state_at_liftoff_minus
# [ 3.99183733e-01  1.40236289e+00 -1.00000000e-01 -2.68879702e-01
#   5.04037106e-01 -2.46583182e+00  5.80928534e+00  1.57816045e-17
#  -1.34679675e-01  5.26163050e+00]
# calculated_state_at_liftoff_minus
# [ 0.2306371   1.33103777 -0.1        -0.39352708  0.5        -3.73482399
#   5.34725381  0.         -0.50504766  6.47846921]
# simulated_beta
# -0.36887970237446566
# calculated_beta
# -0.493527080543416
# FAIL
#
# ======================================================================
# FAIL: test_liftoff_minus_state_5 (TestTakeOffPlus.TestTakeOffPlus)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/notebooks/TestTakeOffPlus.py", line 878, in test_liftoff_minus_state_5
#     self.liftoff_minus_state(apex_state, False)
#   File "/notebooks/TestTakeOffPlus.py", line 962, in liftoff_minus_state
#     self.assertAlmostEqual(
# AssertionError: -0.493527080543416 != -0.36887970237446566 within 1 places (0.12464737816895033 difference)
#
# ----------------------------------------------------------------------
# Ran 1 test in 1.174s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=1 errors=0 failures=1>
