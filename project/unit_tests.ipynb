# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
import unittest
from TestTakeOffPlus import TestTakeOffPlus


suite = unittest.TestLoader().loadTestsFromTestCase(TestTakeOffPlus)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus) ...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <img src="data:image/png;base64,..." width="640">
# START: -6.267
# -0.050000000000000044
# previous_velocity_along_leg_frame
# 1.5000000000000002
# LIFTED OFF!
# STARING
# 1304
# 2295
# TRYING
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# simulated_state_at_liftoff_minus
# [-2.41875545e-01  1.47586379e+00  2.70783429e-17 -2.10826410e-01
#   5.09749974e-01 -1.43861345e+00  5.94862813e+00  2.22044605e-16
#  -1.02916623e-01  2.86328937e+00]
# calculated_state_at_liftoff_minus
# [-0.72993963  1.27832147  0.         -0.56549067  0.5        -4.37144369
#   4.82008407  0.         -0.73929441  6.41207267]
# simulated_beta
# -0.21082641027050952
# calculated_beta
# -0.5654906669790547
# FAIL
#
# ======================================================================
# FAIL: test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/notebooks/TestTakeOffPlus.py", line 835, in test_liftoff_minus_state_1
#     self.liftoff_minus_state(apex_state)
#   File "/notebooks/TestTakeOffPlus.py", line 966, in liftoff_minus_state
#     self.assertAlmostEqual(
# AssertionError: -0.5654906669790547 != -0.21082641027050952 within 1 places (0.3546642567085452 difference)
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.933s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=1 errors=0 failures=1>
