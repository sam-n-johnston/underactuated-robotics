# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
from TestTakeOffPlus import TestTakeOffPlus


suite = unittest.TestLoader().loadTestsFromTestCase(TestTakeOffPlus)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus) ...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <img src="data:image/png;base64,..." width="640">
# tryingit1
# (10, 4099)
# (4099,)
# tryingit2
# (10, 2168)
# tryingit3
# (10, 2168)
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# simulated_state_at_liftoff_minus
# [-0.70863681  0.74641871 -0.12311566 -0.93391968  0.49487879 -5.00097927
#   2.17630735  0.42246068 -3.43791695 12.42416559]
# calculated_state_at_liftoff_minus
# [-0.61132514  1.19391629 -0.2        -0.45064505  0.5        -4.35610706
#   4.42741842  0.          0.          0.        ]
# simulated_beta
# -1.0570353402296844
# calculated_beta
# -0.65064504686426
# FAIL
#
# ======================================================================
# FAIL: test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/notebooks/TestTakeOffPlus.py", line 834, in test_liftoff_minus_state_1
#     self.liftoff_minus_state(apex_state)
#   File "/notebooks/TestTakeOffPlus.py", line 948, in liftoff_minus_state
#     self.assertAlmostEqual(
# AssertionError: -0.65064504686426 != -1.0570353402296844 within 1 places (0.4063902933654244 difference)
#
# ----------------------------------------------------------------------
# Ran 1 test in 1.011s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=1 errors=0 failures=1>
