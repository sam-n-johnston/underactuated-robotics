# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
import unittest
from TestTakeOffPlus import TestTakeOffPlus


suite = unittest.TestLoader().loadTestsFromTestCase(TestTakeOffPlus)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus) ...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <img src="data:image/png;base64,..." width="640">
# START: -6.276
# -0.10000000000000009
# previous_velocity_along_leg_frame
# -0.0
# -6.244429584381986
# 0.0
# -0.6265327947096533
# done
# -6.244429584381986
# -0.6265327947096533
# delta_angular_momentum
# 0.002249235285644617
# delta_angular_momentum
# 0.002251665254887284
# delta_angular_momentum
# 0.0022540249403991634
# delta_angular_momentum
# 0.002256314893050709
# delta_angular_momentum
# 0.0022585356616984403
# delta_angular_momentum
# 0.0022606877931774737
# delta_angular_momentum
# 0.0022627718322942585
# delta_angular_momentum
# 0.0022647883218195144
# delta_angular_momentum
# 0.00226673780248138
# delta_angular_momentum
# 0.0022686208129587618
# delta_angular_momentum
# 0.002270437889874878
# delta_angular_momentum
# 0.0022721895677910156
# delta_angular_momentum
# 0.0022738763792004724
# delta_angular_momentum
# 0.002275498854522701
# delta_angular_momentum
# 0.002277057522097649
# delta_angular_momentum
# 0.0022785529081802893
# delta_angular_momentum
# 0.002279985536935344
# delta_angular_momentum
# 0.0022813559304321954
# delta_angular_momentum
# 0.00228266460863999
# delta_angular_momentum
# 0.002283912089422924
# delta_angular_momentum
# 0.002285098888535717
# delta_angular_momentum
# 0.0022862255196192697
# delta_angular_momentum
# 0.0022872924941965025
# delta_angular_momentum
# 0.002288300321668372
# delta_angular_momentum
# 0.0022892495093100695
# delta_angular_momentum
# 0.0022901405622673975
# delta_angular_momentum
# 0.002290973983553317
# delta_angular_momentum
# 0.002291750274044671
# delta_angular_momentum
# 0.002292469932479085
# delta_angular_momentum
# 0.0022931334554520274
# delta_angular_momentum
# 0.0022937413374140517
# delta_angular_momentum
# 0.0022942940706681967
# delta_angular_momentum
# 0.0022947921453675547
# delta_angular_momentum
# 0.002295236049513008
# delta_angular_momentum
# 0.0022956262689511247
# delta_angular_momentum
# 0.002295963287372216
# delta_angular_momentum
# 0.002296247586308554
# delta_angular_momentum
# 0.0022964796451327473
# delta_angular_momentum
# 0.0022966599410562697
# delta_angular_momentum
# 0.002296788949128153
# delta_angular_momentum
# 0.0022968671422338226
# delta_angular_momentum
# 0.002296894991094093
# delta_angular_momentum
# 0.0022968729642643057
# delta_angular_momentum
# 0.002296801528133624
# delta_angular_momentum
# 0.002296681146924469
# delta_angular_momentum
# 0.0022965122826921055
# delta_angular_momentum
# 0.00229629539532437
# delta_angular_momentum
# 0.0022960309425415367
# delta_angular_momentum
# 0.0022957193798963356
# delta_angular_momentum
# 0.0022953611607740994
# delta_angular_momentum
# 0.002294956736393053
# delta_angular_momentum
# 0.002294506555804742
# delta_angular_momentum
# 0.002294011065894588
# delta_angular_momentum
# 0.002293470711382588
# delta_angular_momentum
# 0.002292885934824138
# delta_angular_momentum
# 0.002292257176610987
# delta_angular_momentum
# 0.0022915848749723296
# delta_angular_momentum
# 0.0022908694659760117
# delta_angular_momentum
# 0.002290111383529873
# delta_angular_momentum
# 0.0022893110593832093
# delta_angular_momentum
# 0.002288468923128361
# delta_angular_momentum
# 0.0022875854022024215
# delta_angular_momentum
# 0.002286660921889062
# delta_angular_momentum
# 0.0022856959053204826
# delta_angular_momentum
# 0.002284690773479475
# delta_angular_momentum
# 0.0022836459452016044
# delta_angular_momentum
# 0.0022825618371775016
# delta_angular_momentum
# 0.002281438863955273
# delta_angular_momentum
# 0.002280277437943018
# delta_angular_momentum
# 0.0022790779694114613
# delta_angular_momentum
# 0.002277840866496685
# delta_angular_momentum
# 0.0022765665352029825
# delta_angular_momentum
# 0.0022752553794058005
# delta_angular_momentum
# 0.0022739078008548012
# delta_angular_momentum
# 0.0022725241991770184
# delta_angular_momentum
# 0.00227110497188012
# delta_angular_momentum
# 0.002269650514355766
# delta_angular_momentum
# 0.0022681612198830695
# delta_angular_momentum
# 0.002266637479632158
# delta_angular_momentum
# 0.002265079682667818
# delta_angular_momentum
# 0.0022634882159532545
# delta_angular_momentum
# 0.002261863464353927
# delta_angular_momentum
# 0.0022602058106414844
# delta_angular_momentum
# 0.002258515635497791
# delta_angular_momentum
# 0.0022567933175190436
# delta_angular_momentum
# 0.0022550392332199706
# delta_angular_momentum
# 0.0022532537570381247
# delta_angular_momentum
# 0.0022514372613382586
# delta_angular_momentum
# 0.002249590116416787
# delta_angular_momentum
# 0.002247712690506323
# delta_angular_momentum
# 0.0022458053497803115
# delta_angular_momentum
# 0.00224386845835773
# delta_angular_momentum
# 0.002241902378307874
# delta_angular_momentum
# 0.0022399074696552185
# delta_angular_momentum
# 0.0022378840903843613
# delta_angular_momentum
# 0.0022358325964450323
# delta_angular_momentum
# 0.0022337533417571866
# delta_angular_momentum
# 0.0022316466782161654
# delta_angular_momentum
# 0.0022295129556979282
# delta_angular_momentum
# 0.002227352522064359
# delta_angular_momentum
# 0.0022251657231686394
# delta_angular_momentum
# 0.002222952902860689
# delta_angular_momentum
# 0.0022207144029926743
# delta_angular_momentum
# 0.0022184505634245855
# delta_angular_momentum
# 0.002216161722029871
# delta_angular_momentum
# 0.002213848214701144
# delta_angular_momentum
# 0.0022115103753559415
# delta_angular_momentum
# 0.002209148535942555
# delta_angular_momentum
# 0.0022067630264459128
# delta_angular_momentum
# 0.002204354174893524
# delta_angular_momentum
# 0.0022019223073614807
# delta_angular_momentum
# 0.002199467747980515
# delta_angular_momentum
# 0.0021969908189421127
# delta_angular_momentum
# 0.002194491840504681
# delta_angular_momentum
# 0.0021919711309997688
# delta_angular_momentum
# 0.0021894290068383386
# delta_angular_momentum
# 0.002186865782517091
# delta_angular_momentum
# 0.0021842817706248362
# delta_angular_momentum
# 0.002181677281848918
# delta_angular_momentum
# 0.002179052624981679
# delta_angular_momentum
# 0.002176408106926984
# delta_angular_momentum
# 0.002173744032706774
# delta_angular_momentum
# 0.002171060705467678
# delta_angular_momentum
# 0.0021683584264876577
# delta_angular_momentum
# 0.0021656374951827028
# delta_angular_momentum
# 0.002162898209113564
# delta_angular_momentum
# 0.0021601408639925247
# delta_angular_momentum
# 0.0021573657536902158
# delta_angular_momentum
# 0.0021545731702424646
# delta_angular_momentum
# 0.002151763403857186
# delta_angular_momentum
# 0.002148936742921309
# delta_angular_momentum
# 0.0021460934740077293
# delta_angular_momentum
# 0.0021432338818823137
# delta_angular_momentum
# 0.0021403582495109204
# delta_angular_momentum
# 0.002137466858066465
# delta_angular_momentum
# 0.0021345599869360106
# delta_angular_momentum
# 0.002131637913727889
# delta_angular_momentum
# 0.0021287009142788556
# delta_angular_momentum
# 0.002125749262661269
# delta_angular_momentum
# 0.0021227832311903005
# delta_angular_momentum
# 0.0021198030904311695
# delta_angular_momentum
# 0.0021168091092064055
# delta_angular_momentum
# 0.0021138015546031345
# delta_angular_momentum
# 0.002110780691980392
# delta_angular_momentum
# 0.0021077467849764525
# delta_angular_momentum
# 0.002104700095516193
# delta_angular_momentum
# 0.002101640883818466
# delta_angular_momentum
# 0.0020985694084035026
# delta_angular_momentum
# 0.002095485926100328
# delta_angular_momentum
# 0.002092390692054202
# delta_angular_momentum
# 0.0020892839597340743
# delta_angular_momentum
# 0.0020861659809400597
# delta_angular_momentum
# 0.0020830370058109253
# delta_angular_momentum
# 0.0020798972828315995
# delta_angular_momentum
# 0.0020767470588406913
# delta_angular_momentum
# 0.0020735865790380273
# delta_angular_momentum
# 0.002070416086992196
# delta_angular_momentum
# 0.0020672358246481165
# delta_angular_momentum
# 0.0020640460323346015
# delta_angular_momentum
# 0.002060846948771951
# delta_angular_momentum
# 0.00205763881107954
# delta_angular_momentum
# 0.002054421854783424
# delta_angular_momentum
# 0.002051196313823955
# delta_angular_momentum
# 0.0020479624205633966
# delta_angular_momentum
# 0.002044720405793558
# delta_angular_momentum
# 0.002041470498743423
# delta_angular_momentum
# 0.002038212927086797
# delta_angular_momentum
# 0.0020349479169499466
# delta_angular_momentum
# 0.002031675692919255
# delta_angular_momentum
# 0.002028396478048876
# delta_angular_momentum
# 0.002025110493868386
# delta_angular_momentum
# 0.002021817960390451
# delta_angular_momentum
# 0.0020185190961184867
# delta_angular_momentum
# 0.002015214118054319
# delta_angular_momentum
# 0.0020119032417058487
# delta_angular_momentum
# 0.002008586681094716
# delta_angular_momentum
# 0.0020052646487639636
# delta_angular_momentum
# 0.0020019373557856966
# delta_angular_momentum
# 0.0019986050117687423
# delta_angular_momentum
# 0.0019952678248663074
# delta_angular_momentum
# 0.0019919260017836316
# delta_angular_momentum
# 0.0019885797477856375
# delta_angular_momentum
# 0.0019852292667045758
# delta_angular_momentum
# 0.001981874760947664
# delta_angular_momentum
# 0.0019785164315047265
# delta_angular_momentum
# 0.001975154477955817
# delta_angular_momentum
# 0.0019717890984788447
# delta_angular_momentum
# 0.001968420489857188
# delta_angular_momentum
# 0.0019650488474873017
# delta_angular_momentum
# 0.0019616743653863154
# delta_angular_momentum
# 0.0019582972361996244
# delta_angular_momentum
# 0.0019549176512084687
# delta_angular_momentum
# 0.0019515358003375065
# delta_angular_momentum
# 0.0019481518721623714
# delta_angular_momentum
# 0.0019447660539172237
# delta_angular_momentum
# 0.0019413785315022878
# delta_angular_momentum
# 0.001937989489491379
# delta_angular_momentum
# 0.0019345991111394162
# delta_angular_momentum
# 0.0019312075783899244
# delta_angular_momentum
# 0.0019278150718825206
# delta_angular_momentum
# 0.0019244217709603897
# delta_angular_momentum
# 0.0019210278536777416
# delta_angular_momentum
# 0.0019176334968072594
# delta_angular_momentum
# 0.0019142388758475262
# delta_angular_momentum
# 0.0019108441650304414
# delta_angular_momentum
# 0.00190744953732862
# delta_angular_momentum
# 0.001904055164462771
# delta_angular_momentum
# 0.001900661216909067
# delta_angular_momentum
# 0.0018972678639064885
# delta_angular_momentum
# 0.001893875273464158
# delta_angular_momentum
# 0.0018904836123686487
# delta_angular_momentum
# 0.0018870930461912815
# delta_angular_momentum
# 0.0018837037392953997
# delta_angular_momentum
# 0.0018803158548436228
# delta_angular_momentum
# 0.0018769295548050871
# delta_angular_momentum
# 0.0018735449999626589
# delta_angular_momentum
# 0.0018701623499201342
# delta_angular_momentum
# 0.001866781763109412
# delta_angular_momentum
# 0.0018634033967976516
# delta_angular_momentum
# 0.0018600274070944061
# delta_angular_momentum
# 0.0018566539489587332
# delta_angular_momentum
# 0.0018532831762062881
# delta_angular_momentum
# 0.0018499152415163893
# delta_angular_momentum
# 0.0018465502964390666
# delta_angular_momentum
# 0.0018431884914020824
# delta_angular_momentum
# 0.0018398299757179325
# delta_angular_momentum
# 0.0018364748975908222
# delta_angular_momentum
# 0.0018331234041236194
# delta_angular_momentum
# 0.001829775641324783
# delta_angular_momentum
# 0.0018264317541152673
# delta_angular_momentum
# 0.001823091886335403
# delta_angular_momentum
# 0.0018197561807517522
# delta_angular_momentum
# 0.001816424779063936
# delta_angular_momentum
# 0.0018130978219114463
# delta_angular_momentum
# 0.0018097754488804161
# delta_angular_momentum
# 0.0018064577985103824
# delta_angular_momentum
# 0.0018031450083010056
# delta_angular_momentum
# 0.001799837214718779
# delta_angular_momentum
# 0.0017965345532036975
# delta_angular_momentum
# 0.00179323715817591
# delta_angular_momentum
# 0.0017899451630423396
# delta_angular_momentum
# 0.0017866587002032775
# delta_angular_momentum
# 0.001783377901058953
# delta_angular_momentum
# 0.0017801028960160706
# delta_angular_momentum
# 0.0017768338144943227
# delta_angular_momentum
# 0.0017735707849328766
# delta_angular_momentum
# 0.001770313934796828
# delta_angular_momentum
# 0.0017670633905836311
# delta_angular_momentum
# 0.001763819277829496
# delta_angular_momentum
# 0.0017605817211157648
# delta_angular_momentum
# 0.001757350844075251
# delta_angular_momentum
# 0.001754126769398554
# delta_angular_momentum
# 0.0017509096188403448
# delta_angular_momentum
# 0.001747699513225623
# delta_angular_momentum
# 0.0017444965724559408
# delta_angular_momentum
# 0.001741300915515603
# delta_angular_momentum
# 0.0017381126604778354
# delta_angular_momentum
# 0.0017349319245109213
# delta_angular_momentum
# 0.0017317588238843114
# delta_angular_momentum
# 0.0017285934739747026
# delta_angular_momentum
# 0.0017254359892720863
# delta_angular_momentum
# 0.0017222864833857693
# delta_angular_momentum
# 0.0017191450690503603
# delta_angular_momentum
# 0.0017160118581317305
# delta_angular_momentum
# 0.0017128869616329406
# delta_angular_momentum
# 0.0017097704897001396
# delta_angular_momentum
# 0.001706662551628433
# delta_angular_momentum
# 0.0017035632558677178
# delta_angular_momentum
# 0.0017004727100284913
# delta_angular_momentum
# 0.0016973910208876242
# delta_angular_momentum
# 0.0016943182943941091
# delta_angular_momentum
# 0.001691254635674771
# delta_angular_momentum
# 0.0016882001490399537
# delta_angular_momentum
# 0.001685154937989172
# delta_angular_momentum
# 0.0016821191052167302
# delta_angular_momentum
# 0.0016790927526173175
# delta_angular_momentum
# 0.0016760759812915636
# delta_angular_momentum
# 0.001673068891551571
# delta_angular_momentum
# 0.00167007158292641
# delta_angular_momentum
# 0.001667084154167585
# delta_angular_momentum
# 0.001664106703254473
# delta_angular_momentum
# 0.001661139327399725
# delta_angular_momentum
# 0.0016581821230546398
# delta_angular_momentum
# 0.001655235185914508
# delta_angular_momentum
# 0.0016522986109239197
# delta_angular_momentum
# 0.0016493724922820479
# delta_angular_momentum
# 0.0016464569234478945
# delta_angular_momentum
# 0.0016435519971455094
# delta_angular_momentum
# 0.001640657805369177
# delta_angular_momentum
# 0.0016377744393885705
# delta_angular_momentum
# 0.0016349019897538778
# delta_angular_momentum
# 0.0016320405463008942
# delta_angular_momentum
# 0.0016291901981560844
# delta_angular_momentum
# 0.0016263510337416133
# delta_angular_momentum
# 0.0016235231407803476
# delta_angular_momentum
# 0.0016207066063008255
# delta_angular_momentum
# 0.001617901516642193
# delta_angular_momentum
# 0.0016151079574591141
# delta_angular_momentum
# 0.001612326013726646
# delta_angular_momentum
# 0.0016095557697450868
# delta_angular_momentum
# 0.001606797309144789
# delta_angular_momentum
# 0.0016040507148909462
# delta_angular_momentum
# 0.001601316069288346
# delta_angular_momentum
# 0.001598593453986095
# delta_angular_momentum
# 0.0015958829499823097
# delta_angular_momentum
# 0.0015931846376287821
# delta_angular_momentum
# 0.0015904985966356108
# delta_angular_momentum
# 0.0015878249060758036
# delta_angular_momentum
# 0.0015851636443898497
# delta_angular_momentum
# 0.001582514889390261
# delta_angular_momentum
# 0.0015798787182660845
# delta_angular_momentum
# 0.001577255207587385
# delta_angular_momentum
# 0.0015746444333096968
# delta_angular_momentum
# 0.001572046470778445
# delta_angular_momentum
# 0.0015694613947333407
# delta_angular_momentum
# 0.001566889279312743
# delta_angular_momentum
# 0.001564330198057991
# delta_angular_momentum
# 0.0015617842239177115
# delta_angular_momentum
# 0.0015592514292520913
# delta_angular_momentum
# 0.001556731885837125
# delta_angular_momentum
# 0.0015542256648688301
# delta_angular_momentum
# 0.0015517328369674362
# delta_angular_momentum
# 0.001549253472181544
# delta_angular_momentum
# 0.0015467876399922547
# delta_angular_momentum
# 0.0015443354093172723
# delta_angular_momentum
# 0.001541896848514977
# delta_angular_momentum
# 0.0015394720253884696
# delta_angular_momentum
# 0.0015370610071895876
# delta_angular_momentum
# 0.0015346638606228953
# delta_angular_momentum
# 0.0015322806518496424
# delta_angular_momentum
# 0.0015299114464916962
# delta_angular_momentum
# 0.0015275563096354497
# delta_angular_momentum
# 0.0015252153058356935
# delta_angular_momentum
# 0.0015228884991194706
# delta_angular_momentum
# 0.001520575952989896
# delta_angular_momentum
# 0.0015182777304299515
# delta_angular_momentum
# 0.0015159938939062546
# delta_angular_momentum
# 0.0015137245053727997
# delta_angular_momentum
# 0.0015114696262746722
# delta_angular_momentum
# 0.0015092293175517355
# delta_angular_momentum
# 0.001507003639642294
# delta_angular_momentum
# 0.0015047926524867253
# delta_angular_momentum
# 0.00150259641553109
# delta_angular_momentum
# 0.0015004149877307145
# delta_angular_momentum
# 0.0014982484275537482
# delta_angular_momentum
# 0.001496096792984693
# delta_angular_momentum
# 0.0014939601415279087
# delta_angular_momentum
# 0.0014918385302110943
# delta_angular_momentum
# 0.0014897320155887416
# delta_angular_momentum
# 0.0014876406537455637
# delta_angular_momentum
# 0.0014855645002999017
# delta_angular_momentum
# 0.0014835036104071013
# delta_angular_momentum
# 0.0014814580387628718
# delta_angular_momentum
# 0.0014794278396066136
# delta_angular_momentum
# 0.0014774130667247266
# delta_angular_momentum
# 0.0014754137734538902
# delta_angular_momentum
# 0.0014734300126843227
# delta_angular_momentum
# 0.0014714618368630178
# delta_angular_momentum
# 0.001469509297996951
# delta_angular_momentum
# 0.0014675724476562704
# delta_angular_momentum
# 0.0014656513369774597
# delta_angular_momentum
# 0.001463746016666479
# delta_angular_momentum
# 0.0014618565370018838
# delta_angular_momentum
# 0.0014599829478379183
# delta_angular_momentum
# 0.001458125298607591
# delta_angular_momentum
# 0.0014562836383257218
# delta_angular_momentum
# 0.001454458015591973
# delta_angular_momentum
# 0.0014526484785938535
# delta_angular_momentum
# 0.0014508550751097052
# delta_angular_momentum
# 0.0014490778525116617
# delta_angular_momentum
# 0.0014473168577685933
# delta_angular_momentum
# 0.0014455721374490261
# delta_angular_momentum
# 0.001443843737724037
# delta_angular_momentum
# 0.0014421317043701372
# delta_angular_momentum
# 0.0014404360827721247
# delta_angular_momentum
# 0.0014387569179259217
# delta_angular_momentum
# 0.0014370942544413923
# delta_angular_momentum
# 0.0014354481365451372
# delta_angular_momentum
# 0.0014338186080832683
# delta_angular_momentum
# 0.0014322057125241664
# delta_angular_momentum
# 0.0014306094929612179
# delta_angular_momentum
# 0.00142902999211553
# delta_angular_momentum
# 0.00142746725233863
# delta_angular_momentum
# 0.0014259213156151435
# delta_angular_momentum
# 0.0014243922235654541
# delta_angular_momentum
# 0.0014228800174483436
# delta_angular_momentum
# 0.0014213847381636178
# delta_angular_momentum
# 0.0014199064262547065
# delta_angular_momentum
# 0.0014184451219112547
# delta_angular_momentum
# 0.0014170008649716866
# delta_angular_momentum
# 0.0014155736949257602
# delta_angular_momentum
# 0.0014141636509170969
# delta_angular_momentum
# 0.0014127707717457015
# delta_angular_momentum
# 0.001411395095870457
# delta_angular_momentum
# 0.0014100366614116097
# delta_angular_momentum
# 0.001408695506153233
# delta_angular_momentum
# 0.0014073716675456773
# delta_angular_momentum
# 0.0014060651827080006
# delta_angular_momentum
# 0.0014047760884303867
# delta_angular_momentum
# 0.0014035044211765438
# delta_angular_momentum
# 0.0014022502170860918
# delta_angular_momentum
# 0.0014010135119769285
# delta_angular_momentum
# 0.0013997943413475871
# delta_angular_momentum
# 0.0013985927403795694
# delta_angular_momentum
# 0.001397408743939677
# delta_angular_momentum
# 0.0013962423865823133
# delta_angular_momentum
# 0.0013950937025517828
# delta_angular_momentum
# 0.0013939627257845701
# delta_angular_momentum
# 0.0013928494899116055
# delta_angular_momentum
# 0.001391754028260517
# delta_angular_momentum
# 0.001390676373857871
# delta_angular_momentum
# 0.0013896165594313942
# delta_angular_momentum
# 0.0013885746174121883
# delta_angular_momentum
# 0.0013875505799369262
# delta_angular_momentum
# 0.0013865444788500397
# delta_angular_momentum
# 0.0013855563457058906
# delta_angular_momentum
# 0.0013845862117709325
# delta_angular_momentum
# 0.0013836341080258596
# delta_angular_momentum
# 0.0013827000651677399
# delta_angular_momentum
# 0.0013817841136121427
# delta_angular_momentum
# 0.0013808862834952496
# delta_angular_momentum
# 0.0013800066046759547
# delta_angular_momentum
# 0.0013791451067379568
# delta_angular_momentum
# 0.0013783018189918337
# delta_angular_momentum
# 0.0013774767704771156
# delta_angular_momentum
# 0.001376669989964337
# delta_angular_momentum
# 0.0013758815059570861
# delta_angular_momentum
# 0.0013751113466940403
# delta_angular_momentum
# 0.0013743595401509922
# delta_angular_momentum
# 0.0013736261140428656
# delta_angular_momentum
# 0.0013729110958257238
# delta_angular_momentum
# 0.0013722145126987655
# delta_angular_momentum
# 0.0013715363916063106
# delta_angular_momentum
# 0.0013708767592397835
# delta_angular_momentum
# 0.0013702356420396795
# delta_angular_momentum
# 0.0013696130661975277
# delta_angular_momentum
# 0.001369009057657843
# delta_angular_momentum
# 0.001368423642120071
# delta_angular_momentum
# 0.0013678568450405252
# delta_angular_momentum
# 0.0013673086916343134
# delta_angular_momentum
# 0.0013667792068772612
# delta_angular_momentum
# 0.001366268415507825
# delta_angular_momentum
# 0.001365776342028997
# delta_angular_momentum
# 0.0013653030107102044
# delta_angular_momentum
# 0.0013648484455892037
# delta_angular_momentum
# 0.001364412670473965
# delta_angular_momentum
# 0.0013639957089445509
# delta_angular_momentum
# 0.0013635975843549904
# delta_angular_momentum
# 0.0013632183198351456
# delta_angular_momentum
# 0.0013628579382925728
# delta_angular_momentum
# 0.0013625164624143774
# delta_angular_momentum
# 0.0013621939146690654
# delta_angular_momentum
# 0.0013618903173083863
# delta_angular_momentum
# 0.0013616056923691736
# delta_angular_momentum
# 0.0013613400616751808
# delta_angular_momentum
# 0.0013610934468389097
# delta_angular_momentum
# 0.001360865869263438
# delta_angular_momentum
# 0.0013606573501442393
# delta_angular_momentum
# 0.001360467910471002
# delta_angular_momentum
# 0.0013602975710294415
# delta_angular_momentum
# 0.0013601463524031117
# delta_angular_momentum
# 0.0013600142749752102
# delta_angular_momentum
# 0.0013599013589303836
# delta_angular_momentum
# 0.0013598076242565245
# delta_angular_momentum
# 0.0013597330907465725
# delta_angular_momentum
# 0.0013596777780003066
# delta_angular_momentum
# 0.0013596417054261383
# delta_angular_momentum
# 0.0013596248922429022
# delta_angular_momentum
# 0.0013596273574816432
# delta_angular_momentum
# 0.001359649119987401
# delta_angular_momentum
# 0.0013596901984209999
# delta_angular_momentum
# 0.0013597506112608248
# delta_angular_momentum
# 0.0013598303768046097
# delta_angular_momentum
# 0.0013599295131712119
# delta_angular_momentum
# 0.001360048038302398
# delta_angular_momentum
# 0.0013601859699646174
# delta_angular_momentum
# 0.0013603433257507853
# delta_angular_momentum
# 0.0013605201230820598
# delta_angular_momentum
# 0.0013607163792096174
# delta_angular_momentum
# 0.0013609321112164358
# delta_angular_momentum
# 0.0013611673360190697
# delta_angular_momentum
# 0.001361422070369431
# delta_angular_momentum
# 0.0013616963308565675
# delta_angular_momentum
# 0.0013619901339084455
# delta_angular_momentum
# 0.0013623034957937305
# delta_angular_momentum
# 0.0013626364326235706
# delta_angular_momentum
# 0.001362988960353381
# delta_angular_momentum
# 0.0013633610947846298
# delta_angular_momentum
# 0.001363752851566628
# delta_angular_momentum
# 0.001364164246198317
# delta_angular_momentum
# 0.0013645952940300632
# delta_angular_momentum
# 0.0013650460102654525
# delta_angular_momentum
# 0.0013655164099630865
# delta_angular_momentum
# 0.0013660065080383838
# delta_angular_momentum
# 0.0013665163192653847
# delta_angular_momentum
# 0.001367045858278556
# delta_angular_momentum
# 0.001367595139574601
# delta_angular_momentum
# 0.0013681641775142744
# delta_angular_momentum
# 0.0013687529863241985
# delta_angular_momentum
# 0.0013693615800986862
# delta_angular_momentum
# 0.0013699899728015644
# delta_angular_momentum
# 0.0013706381782680056
# delta_angular_momentum
# 0.0013713062102063622
# delta_angular_momentum
# 0.0013719940822000056
# delta_angular_momentum
# 0.0013727018077091702
# delta_angular_momentum
# 0.0013734294000728028
# delta_angular_momentum
# 0.0013741768725104176
# delta_angular_momentum
# 0.0013749442381239562
# delta_angular_momentum
# 0.0013757315098996547
# delta_angular_momentum
# 0.001376538700709912
# delta_angular_momentum
# 0.0013773658233151719
# delta_angular_momentum
# 0.0013782128903658054
# delta_angular_momentum
# 0.0013790799144040003
# delta_angular_momentum
# 0.0013799669078656607
# delta_angular_momentum
# 0.0013808738830823092
# delta_angular_momentum
# 0.0013818008522829995
# delta_angular_momentum
# 0.0013827478275962337
# delta_angular_momentum
# 0.0013837148210518885
# delta_angular_momentum
# 0.0013847018445831475
# delta_angular_momentum
# 0.001385708910028445
# delta_angular_momentum
# 0.0013867360291334129
# delta_angular_momentum
# 0.0013877832135528376
# delta_angular_momentum
# 0.0013888504748526267
# delta_angular_momentum
# 0.0013899378245117837
# delta_angular_momentum
# 0.0013910452739243882
# delta_angular_momentum
# 0.0013921728344015911
# delta_angular_momentum
# 0.0013933205171736125
# delta_angular_momentum
# 0.0013944883333917525
# delta_angular_momentum
# 0.0013956762941304119
# delta_angular_momentum
# 0.0013968844103891185
# delta_angular_momentum
# 0.0013981126930945704
# delta_angular_momentum
# 0.0013993611531026794
# delta_angular_momentum
# 0.0014006298012006352
# delta_angular_momentum
# 0.0014019186481089702
# delta_angular_momentum
# 0.0014032277044836441
# delta_angular_momentum
# 0.0014045569809181307
# delta_angular_momentum
# 0.0014059064879455216
# delta_angular_momentum
# 0.0014072762360406374
# delta_angular_momentum
# 0.0014086662356221533
# delta_angular_momentum
# 0.0014100764970547324
# delta_angular_momentum
# 0.0014115070306511747
# delta_angular_momentum
# 0.001412957846674575
# delta_angular_momentum
# 0.0014144289553404926
# delta_angular_momentum
# 0.0014159203668191354
# delta_angular_momentum
# 0.0014174320912375552
# delta_angular_momentum
# 0.0014189641386818546
# delta_angular_momentum
# 0.001420516519199407
# delta_angular_momentum
# 0.0014220892428010918
# delta_angular_momentum
# 0.001423682319463538
# delta_angular_momentum
# 0.0014252957591313863
# delta_angular_momentum
# 0.0014269295717195597
# delta_angular_momentum
# 0.0014285837671155512
# delta_angular_momentum
# 0.001430258355181723
# delta_angular_momentum
# 0.0014319533457576219
# delta_angular_momentum
# 0.0014336687486623052
# delta_angular_momentum
# 0.0014354045736966858
# delta_angular_momentum
# 0.0014371608306458863
# delta_angular_momentum
# 0.0014389375292816109
# delta_angular_momentum
# 0.001440734679364532
# delta_angular_momentum
# 0.001442552290646692
# delta_angular_momentum
# 0.0014443903728739167
# delta_angular_momentum
# 0.0014462489357882494
# delta_angular_momentum
# 0.001448127989130395
# delta_angular_momentum
# 0.0014500275426421838
# delta_angular_momentum
# 0.0014519476060690492
# delta_angular_momentum
# 0.001453888189162522
# delta_angular_momentum
# 0.0014558493016827388
# delta_angular_momentum
# 0.0014578309534009697
# delta_angular_momentum
# 0.0014598331541021592
# delta_angular_momentum
# 0.0014618559135874884
# delta_angular_momentum
# 0.0014638992416769472
# delta_angular_momentum
# 0.0014659631482119284
# delta_angular_momentum
# 0.0014680476430578384
# delta_angular_momentum
# 0.0014701527361067233
# delta_angular_momentum
# 0.0014722784372799109
# delta_angular_momentum
# 0.0014744247565306775
# delta_angular_momentum
# 0.0014765917038469213
# delta_angular_momentum
# 0.0014787792892538643
# delta_angular_momentum
# 0.0014809875228167647
# delta_angular_momentum
# 0.0014832164146436513
# delta_angular_momentum
# 0.0014854659748880733
# delta_angular_momentum
# 0.0014877362137518722
# delta_angular_momentum
# 0.001490027141487969
# delta_angular_momentum
# 0.0014923387684031711
# delta_angular_momentum
# 0.0014946711048609987
# delta_angular_momentum
# 0.001497024161284529
# delta_angular_momentum
# 0.001499397948159261
# delta_angular_momentum
# 0.0015017924760359987
# delta_angular_momentum
# 0.0015042077555337515
# delta_angular_momentum
# 0.001506643797342659
# delta_angular_momentum
# 0.0015091006122269336
# delta_angular_momentum
# 0.0015115782110278182
# delta_angular_momentum
# 0.0015140766046665703
# delta_angular_momentum
# 0.0015165958041474656
# delta_angular_momentum
# 0.0015191358205608146
# delta_angular_momentum
# 0.0015216966650860096
# delta_angular_momentum
# 0.0015242783489945865
# delta_angular_momentum
# 0.0015268808836533048
# delta_angular_momentum
# 0.0015295042805272567
# delta_angular_momentum
# 0.0015321485511829885
# delta_angular_momentum
# 0.0015348137072916461
# delta_angular_momentum
# 0.0015374997606321444
# delta_angular_momentum
# 0.001540206723094354
# delta_angular_momentum
# 0.0015429346066823109
# delta_angular_momentum
# 0.0015456834235174472
# delta_angular_momentum
# 0.0015484531858418438
# delta_angular_momentum
# 0.0015512439060215038
# delta_angular_momentum
# 0.0015540555965496512
# delta_angular_momentum
# 0.001556888270050045
# delta_angular_momentum
# 0.0015597419392803212
# delta_angular_momentum
# 0.001562616617135355
# delta_angular_momentum
# 0.0015655123166506434
# delta_angular_momentum
# 0.0015684290510057143
# delta_angular_momentum
# 0.0015713668335275517
# delta_angular_momentum
# 0.0015743256776940514
# delta_angular_momentum
# 0.0015773055971374916
# delta_angular_momentum
# 0.0015803066056480318
# delta_angular_momentum
# 0.001583328717177231
# delta_angular_momentum
# 0.0015863719458415917
# delta_angular_momentum
# 0.001589436305926124
# delta_angular_momentum
# 0.0015925218118879338
# delta_angular_momentum
# 0.001595628478359836
# delta_angular_momentum
# 0.0015987563201539901
# delta_angular_momentum
# 0.0016019053522655542
# delta_angular_momentum
# 0.0016050755898763714
# delta_angular_momentum
# 0.0016082670483586715
# delta_angular_momentum
# 0.0016114797432788027
# delta_angular_momentum
# 0.0016147136904009804
# delta_angular_momentum
# 0.0016179689056910651
# delta_angular_momentum
# 0.0016212454053203627
# delta_angular_momentum
# 0.0016245432056694454
# delta_angular_momentum
# 0.0016278623233320028
# delta_angular_momentum
# 0.0016312027751187075
# delta_angular_momentum
# 0.0016345645780611177
# delta_angular_momentum
# 0.0016379477494155885
# delta_angular_momentum
# 0.001641352306667222
# delta_angular_momentum
# 0.0016447782675338303
# delta_angular_momentum
# 0.0016482256499699291
# delta_angular_momentum
# 0.001651694472170753
# delta_angular_momentum
# 0.0016551847525762952
# delta_angular_momentum
# 0.001658696509875374
# delta_angular_momentum
# 0.0016622297630097174
# delta_angular_momentum
# 0.0016657845311780814
# delta_angular_momentum
# 0.001669360833840381
# delta_angular_momentum
# 0.0016729586907218593
# delta_angular_momentum
# 0.0016765781218172683
# delta_angular_momentum
# 0.001680219147395081
# delta_angular_momentum
# 0.001683881788001729
# delta_angular_momentum
# 0.0016875660644658582
# delta_angular_momentum
# 0.001691271997902616
# delta_angular_momentum
# 0.0016949996097179597
# delta_angular_momentum
# 0.001698748921612986
# delta_angular_momentum
# 0.0017025199555882951
# delta_angular_momentum
# 0.0017063127339483671
# delta_angular_momentum
# 0.001710127279305971
# delta_angular_momentum
# 0.0017139636145865964
# delta_angular_momentum
# 0.001717821763032908
# delta_angular_momentum
# 0.0017217017482092252
# delta_angular_momentum
# 0.0017256035940060278
# delta_angular_momentum
# 0.0017295273246444836
# delta_angular_momentum
# 0.0017334729646810037
# delta_angular_momentum
# 0.001737440539011817
# delta_angular_momentum
# 0.0017414300728775748
# delta_angular_momentum
# 0.0017454415918679762
# delta_angular_momentum
# 0.0017494751219264163
# delta_angular_momentum
# 0.0017535306893546642
# delta_angular_momentum
# 0.0017576083208175601
# delta_angular_momentum
# 0.0017617080433477374
# delta_angular_momentum
# 0.0017658298843503705
# delta_angular_momentum
# 0.001769973871607946
# delta_angular_momentum
# 0.0017741400332850555
# delta_angular_momentum
# 0.0017783283979332155
# delta_angular_momentum
# 0.00178253899449571
# delta_angular_momentum
# 0.0017867718523124567
# delta_angular_momentum
# 0.0017910270011248944
# delta_angular_momentum
# 0.0017953044710808976
# delta_angular_momentum
# 0.0017996042927397133
# delta_angular_momentum
# 0.0018039264970769206
# delta_angular_momentum
# 0.001808271115489413
# delta_angular_momentum
# 0.0018126381798004062
# delta_angular_momentum
# 0.0018170277222644652
# delta_angular_momentum
# 0.0018214397755725587
# delta_angular_momentum
# 0.0018258743728571316
# delta_angular_momentum
# 0.0018303315476972067
# delta_angular_momentum
# 0.0018348113341235001
# delta_angular_momentum
# 0.0018393137666235671
# delta_angular_momentum
# 0.0018438388801469657
# delta_angular_momentum
# 0.001848386710110445
# delta_angular_momentum
# 0.001852957292403153
# delta_angular_momentum
# 0.0018575506633918685
# delta_angular_momentum
# 0.0018621668599262547
# delta_angular_momentum
# 0.0018668059193441317
# delta_angular_momentum
# 0.0018714678794767728
# delta_angular_momentum
# 0.0018761527786542234
# delta_angular_momentum
# 0.0018808606557106369
# delta_angular_momentum
# 0.0018855915499896344
# delta_angular_momentum
# 0.001890345501349685
# delta_angular_momentum
# 0.0018951225501695056
# delta_angular_momentum
# 0.001899922737353482
# delta_angular_momentum
# 0.001904746104337109
# delta_angular_momentum
# 0.001909592693092453
# delta_angular_momentum
# 0.0019144625461336305
# delta_angular_momentum
# 0.0019193557065223085
# delta_angular_momentum
# 0.0019242722178732258
# delta_angular_momentum
# 0.0019292121243597298
# delta_angular_momentum
# 0.0019341754707193342
# delta_angular_momentum
# 0.0019391623022592956
# delta_angular_momentum
# 0.0019441726648622103
# delta_angular_momentum
# 0.0019492066049916215
# delta_angular_momentum
# 0.0019542641696976555
# delta_angular_momentum
# 0.0019593454066226678
# delta_angular_momentum
# 0.00196445036400691
# delta_angular_momentum
# 0.0019695790906942108
# delta_angular_momentum
# 0.0019747316361376794
# delta_angular_momentum
# 0.001979908050405418
# delta_angular_momentum
# 0.0019851083841862602
# delta_angular_momentum
# 0.001990332688795515
# delta_angular_momentum
# 0.001995581016180733
# delta_angular_momentum
# 0.0020008534189274916
# delta_angular_momentum
# 0.002006149950265184
# delta_angular_momentum
# 0.002011470664072831
# delta_angular_momentum
# 0.002016815614884912
# delta_angular_momentum
# 0.0020221848578971984
# delta_angular_momentum
# 0.0020275784489726086
# delta_angular_momentum
# 0.002032996444647076
# delta_angular_momentum
# 0.00203843890213543
# delta_angular_momentum
# 0.0020439058793372857
# delta_angular_momentum
# 0.0020493974348429547
# delta_angular_momentum
# 0.00205491362793936
# delta_angular_momentum
# 0.0020604545186159685
# delta_angular_momentum
# 0.00206602016757073
# delta_angular_momentum
# 0.0020716106362160323
# delta_angular_momentum
# 0.0020772259866846656
# delta_angular_momentum
# 0.002082866281835794
# delta_angular_momentum
# 0.002088531585260942
# delta_angular_momentum
# 0.002094221961289987
# delta_angular_momentum
# 0.0020999374749971662
# delta_angular_momentum
# 0.0021056781922070807
# delta_angular_momentum
# 0.002111444179500724
# delta_angular_momentum
# 0.0021172355042215073
# delta_angular_momentum
# 0.002123052234481298
# delta_angular_momentum
# 0.002128894439166457
# delta_angular_momentum
# 0.0021347621879438975
# delta_angular_momentum
# 0.002140655551267135
# delta_angular_momentum
# 0.0021465746003823507
# delta_angular_momentum
# 0.002152519407334464
# delta_angular_momentum
# 0.002158490044973201
# delta_angular_momentum
# 0.00216448658695917
# delta_angular_momentum
# 0.0021705091077699494
# delta_angular_momentum
# 0.0021765576827061685
# delta_angular_momentum
# 0.0021826323878975946
# delta_angular_momentum
# 0.002188733300309228
# delta_angular_momentum
# 0.002194860497747391
# delta_angular_momentum
# 0.0022010140588658235
# delta_angular_momentum
# 0.002207194063171781
# delta_angular_momentum
# 0.0022134005910321272
# delta_angular_momentum
# 0.002219633723679433
# delta_angular_momentum
# 0.0022258935432180717
# delta_angular_momentum
# 0.002232180132630312
# delta_angular_momentum
# 0.002238493575782416
# delta_angular_momentum
# 0.0022448339574307266
# delta_angular_momentum
# 0.002251201363227756
# delta_angular_momentum
# 0.0022575958797282775
# delta_angular_momentum
# 0.0022640175943954
# delta_angular_momentum
# 0.00227046659560665
# delta_angular_momentum
# 0.0022769429726600446
# delta_angular_momentum
# 0.0022834468157801554
# delta_angular_momentum
# 0.0022899782161241774
# delta_angular_momentum
# 0.002296537265787975
# delta_angular_momentum
# 0.0023031240578121376
# delta_angular_momentum
# 0.0023097386861880144
# delta_angular_momentum
# 0.0023163812458637492
# delta_angular_momentum
# 0.0023230518327503006
# delta_angular_momentum
# 0.0023297505437274582
# delta_angular_momentum
# 0.002336477476649843
# delta_angular_momentum
# 0.0023432327303528964
# delta_angular_momentum
# 0.0023500164046588697
# delta_angular_momentum
# 0.0023568286003827826
# delta_angular_momentum
# 0.0023636694193383844
# delta_angular_momentum
# 0.0023705389643440926
# delta_angular_momentum
# 0.0023774373392289236
# delta_angular_momentum
# 0.0023843646488384026
# delta_angular_momentum
# 0.0023913209990404634
# delta_angular_momentum
# 0.0023983064967313303
# delta_angular_momentum
# 0.0024053212498413782
# delta_angular_momentum
# 0.0024123653673409854
# delta_angular_momentum
# 0.002419438959246357
# delta_angular_momentum
# 0.0024265421366253385
# delta_angular_momentum
# 0.0024336750116032034
# delta_angular_momentum
# 0.002440837697368422
# delta_angular_momentum
# 0.002448030308178415
# delta_angular_momentum
# 0.002455252959365273
# delta_angular_momentum
# 0.0024625057673414662
# delta_angular_momentum
# 0.0024697888496055223
# delta_angular_momentum
# 0.002477102324747686
# delta_angular_momentum
# 0.0024844463124555458
# delta_angular_momentum
# 0.0024918209335196458
# delta_angular_momentum
# 0.0024992263098390626
# delta_angular_momentum
# 0.00250666256442696
# delta_angular_momentum
# 0.0025141298214161126
# delta_angular_momentum
# 0.002521628206064402
# delta_angular_momentum
# 0.002529157844760284
# delta_angular_momentum
# 0.002536718865028228
# delta_angular_momentum
# 0.0025443113955341177
# delta_angular_momentum
# 0.002551935566090628
# delta_angular_momentum
# 0.0025595915076625656
# delta_angular_momentum
# 0.0025672793523721787
# delta_angular_momentum
# 0.002574999233504424
# delta_angular_momentum
# 0.002582751285512214
# delta_angular_momentum
# 0.0025905356440216105
# delta_angular_momentum
# 0.0025983524458369983
# delta_angular_momentum
# 0.0026062018289462066
# delta_angular_momentum
# 0.002614083932525602
# delta_angular_momentum
# 0.0026219988969451383
# delta_angular_momentum
# 0.0026299468637733647
# delta_angular_momentum
# 0.0026379279757823984
# delta_angular_momentum
# 0.002645942376952848
# delta_angular_momentum
# 0.0026539902124786993
# delta_angular_momentum
# 0.002662071628772158
# delta_angular_momentum
# 0.002670186773468442
# delta_angular_momentum
# 0.002678335795430535
# delta_angular_momentum
# 0.0026865188447538916
# delta_angular_momentum
# 0.002694736072771092
# delta_angular_momentum
# 0.002702987632056452
# delta_angular_momentum
# 0.0027112736764305866
# delta_angular_momentum
# 0.0027195943609649147
# delta_angular_momentum
# 0.002727949841986123
# delta_angular_momentum
# 0.0027363402770805723
# delta_angular_momentum
# 0.002744765825098652
# delta_angular_momentum
# 0.0027532266461590825
# delta_angular_momentum
# 0.0027617229016531635
# delta_angular_momentum
# 0.0027702547542489617
# delta_angular_momentum
# 0.002778822367895451
# delta_angular_momentum
# 0.0027874259078265857
# delta_angular_momentum
# 0.0027960655405653238
# delta_angular_momentum
# 0.002804741433927587
# delta_angular_momentum
# 0.002813453757026156
# delta_angular_momentum
# 0.0028222026802745158
# delta_angular_momentum
# 0.0028309883753906326
# delta_angular_momentum
# 0.0028398110154006597
# delta_angular_momentum
# 0.0028486707746425972
# delta_angular_momentum
# 0.002857567828769872
# delta_angular_momentum
# 0.0028665023547548543
# delta_angular_momentum
# 0.0028754745308923173
# delta_angular_momentum
# 0.0028844845368028115
# delta_angular_momentum
# 0.002893532553435988
# delta_angular_momentum
# 0.002902618763073835
# delta_angular_momentum
# 0.002911743349333863
# delta_angular_momentum
# 0.0029209064971721962
# delta_angular_momentum
# 0.002930108392886609
# delta_angular_momentum
# 0.0029393492241194747
# delta_angular_momentum
# 0.0029486291798606554
# delta_angular_momentum
# 0.0029579484504502966
# delta_angular_momentum
# 0.0029673072275815627
# delta_angular_momentum
# 0.002976705704303279
# delta_angular_momentum
# 0.0029861440750225086
# delta_angular_momentum
# 0.002995622535507041
# delta_angular_momentum
# 0.0030051412828877994
# delta_angular_momentum
# 0.0030147005156611747
# delta_angular_momentum
# 0.0030243004336912593
# delta_angular_momentum
# 0.003033941238212019
# delta_angular_momentum
# 0.0030436231318293604
# delta_angular_momentum
# 0.003053346318523125
# delta_angular_momentum
# 0.0030631110036489872
# delta_angular_momentum
# 0.0030729173939402707
# delta_angular_momentum
# 0.0030827656975096723
# delta_angular_momentum
# 0.003092656123850898
# delta_angular_momentum
# 0.0031025888838402
# delta_angular_momentum
# 0.0031125641897378374
# delta_angular_momentum
# 0.003122582255189424
# delta_angular_momentum
# 0.0031326432952271943
# delta_angular_momentum
# 0.003142747526271173
# delta_angular_momentum
# 0.0031528951661302456
# delta_angular_momentum
# 0.0031630864340031297
# delta_angular_momentum
# 0.0031733215504792488
# delta_angular_momentum
# 0.0031836007375395095
# delta_angular_momentum
# 0.0031939242185569762
# delta_angular_momentum
# 0.0032042922182974444
# delta_angular_momentum
# 0.003214704962919905
# delta_angular_momentum
# 0.003225162679976919
# delta_angular_momentum
# 0.0032356655984148715
# delta_angular_momentum
# 0.0032462139485741315
# delta_angular_momentum
# 0.003256807962189094
# delta_angular_momentum
# 0.0032674478723881324
# delta_angular_momentum
# 0.003278133913693415
# delta_angular_momentum
# 0.003288866322020638
# delta_angular_momentum
# 0.00329964533467863
# delta_angular_momentum
# 0.003310471190368848
# delta_angular_momentum
# 0.0033213441291847696
# delta_angular_momentum
# 0.003332264392611155
# delta_angular_momentum
# 0.003343232223523209
# delta_angular_momentum
# 0.0033542478661856153
# delta_angular_momentum
# 0.0033653115662514613
# delta_angular_momentum
# 0.0033764235707610373
# delta_angular_momentum
# 0.0033875841281405254
# delta_angular_momentum
# 0.003398793488200558
# delta_angular_momentum
# 0.0034100519021346633
# delta_angular_momentum
# 0.003421359622517582
# delta_angular_momentum
# 0.0034327169033034634
# delta_angular_momentum
# 0.0034441239998239397
# delta_angular_momentum
# 0.003455581168786065
# delta_angular_momentum
# 0.0034670886682701433
# delta_angular_momentum
# 0.0034786467577274122
# delta_angular_momentum
# 0.0034902556979776113
# delta_angular_momentum
# 0.003501915751206413
# delta_angular_momentum
# 0.003513627180962723
# delta_angular_momentum
# 0.0035253902521558563
# delta_angular_momentum
# 0.0035372052310525723
# delta_angular_momentum
# 0.0035490723852739823
# delta_angular_momentum
# 0.003560991983792316
# delta_angular_momentum
# 0.0035729642969275595
# delta_angular_momentum
# 0.0035849895963439523
# delta_angular_momentum
# 0.003597068155046349
# delta_angular_momentum
# 0.00360920024737644
# delta_angular_momentum
# 0.0036213861490088347
# delta_angular_momentum
# 0.003633626136947002
# delta_angular_momentum
# 0.003645920489519077
# delta_angular_momentum
# 0.0036582694863735144
# delta_angular_momentum
# 0.003670673408474601
# delta_angular_momentum
# 0.0036831325380978354
# delta_angular_momentum
# 0.0036956471588251464
# delta_angular_momentum
# 0.0037082175555399775
# delta_angular_momentum
# 0.0037208440144222157
# delta_angular_momentum
# 0.0037335268229429764
# delta_angular_momentum
# 0.003746266269859245
# delta_angular_momentum
# 0.0037590626452083534
# delta_angular_momentum
# 0.0037719162403023277
# delta_angular_momentum
# 0.003784827347722058
# delta_angular_momentum
# 0.0037977962613113406
# delta_angular_momentum
# 0.0038108232761707534
# delta_angular_momentum
# 0.003823908688651375
# delta_angular_momentum
# 0.00383705279634836
# delta_angular_momentum
# 0.0038502558980943458
# delta_angular_momentum
# 0.003863518293952715
# delta_angular_momentum
# 0.003876840285210685
# delta_angular_momentum
# 0.003890222174372259
# delta_angular_momentum
# 0.003903664265150995
# delta_angular_momentum
# 0.003917166862462635
# delta_angular_momentum
# 0.003930730272417559
# delta_angular_momentum
# 0.0039443548023130855
# delta_angular_momentum
# 0.003958040760625606
# delta_angular_momentum
# 0.003971788457002554
# delta_angular_momentum
# 0.003985598202254218
# delta_angular_momentum
# 0.003999470308345378
# delta_angular_momentum
# 0.004013405088386786
# delta_angular_momentum
# 0.0040274028566264775
# delta_angular_momentum
# 0.004041463928440916
# delta_angular_momentum
# 0.0040555886203259605
# delta_angular_momentum
# 0.004069777249887683
# delta_angular_momentum
# 0.004084030135832999
# delta_angular_momentum
# 0.004098347597960142
# delta_angular_momentum
# 0.0041127299571489485
# delta_angular_momentum
# 0.004127177535350996
# delta_angular_momentum
# 0.004141690655579556
# delta_angular_momentum
# 0.00415626964189936
# delta_angular_momentum
# 0.004170914819416227
# LIFTED OFF!
# STARING
# 1306
# 2286
# TRYING
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# simulated_state_at_liftoff_minus
# [-5.67554790e-01  1.31804667e+00  2.97513624e-17 -4.97993252e-01
#   4.98054649e-01 -3.44045525e+00  5.15740555e+00  5.53127734e-16
#  -3.74747422e-01  6.16558145e+00]
# calculated_state_at_liftoff_minus
# [-0.12893279  1.48672473  0.         -0.18652326  0.5        -1.70929743
#   6.03865108  0.         -0.37329689  0.        ]
# simulated_beta
# -0.4979932515779103
# calculated_beta
# -0.18652326059773447
# FAIL
#
# ======================================================================
# FAIL: test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/notebooks/TestTakeOffPlus.py", line 835, in test_liftoff_minus_state_1
#     self.liftoff_minus_state(apex_state)
#   File "/notebooks/TestTakeOffPlus.py", line 966, in liftoff_minus_state
#     self.assertAlmostEqual(
# AssertionError: -0.18652326059773447 != -0.4979932515779103 within 1 places (0.3114699909801758 difference)
#
# ----------------------------------------------------------------------
# Ran 1 test in 1.164s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=1 errors=0 failures=1>
