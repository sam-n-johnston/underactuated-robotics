# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
from TestTakeOffPlus import TestTakeOffPlus


suite = unittest.TestLoader().loadTestsFromTestCase(TestTakeOffPlus)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus) ...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# simulated_state_at_liftoff_minus
# [-8.23429172e-01  1.07378774e+00 -1.50000000e-01 -6.29407093e-01
#   4.98959992e-01 -5.00942861e+00  3.64149260e+00 -4.46841996e-17
#  -7.19327348e-01  6.02598839e+00]
# calculated_state_at_liftoff_minus
# [-1.09520913  0.7199719  -0.15       -0.92021657  0.5        -7.36859151
#   0.44160446  0.          0.          0.        ]
# simulated_beta
# -0.7794070929168742
# calculated_beta
# -1.0702165748793746
# FAIL
#
# ======================================================================
# FAIL: test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/notebooks/TestTakeOffPlus.py", line 834, in test_liftoff_minus_state_1
#     self.liftoff_minus_state(apex_state)
#   File "/notebooks/TestTakeOffPlus.py", line 944, in liftoff_minus_state
#     self.assertAlmostEqual(
# AssertionError: -1.0702165748793746 != -0.7794070929168742 within 1 places (0.29080948196250045 difference)
#
# ----------------------------------------------------------------------
# Ran 1 test in 1.028s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=1 errors=0 failures=1>
