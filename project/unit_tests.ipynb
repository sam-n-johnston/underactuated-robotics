# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
import unittest
from TestTakeOffPlus import TestTakeOffPlus


 
suite = unittest.TestLoader().loadTestsFromTestCase(TestTakeOffPlus)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus) ...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <img src="data:image/png;base64,..." width="640">
# touchdown!
# [ 0.          1.49250625  0.         -0.1         0.5         0.
#  -6.27578236  0.          0.          0.        ]
# START: -6.276
# -0.10000000000000009
# previous_velocity_along_leg_frame
# 1.5
# LIFTED OFF!
# [-1.95502179e-04  1.50248662e+00  0.00000000e+00 -1.00130990e-01
#   5.00000000e-01 -3.91001787e-01 -3.92827697e-02  0.00000000e+00
#  -2.61980095e-01  0.00000000e+00]
# 0.0005
# STARING
# 1306
# 2286
# TRYING1
# (10, 2286)
# (10, 2)
# TRYING2
# (10, 2286)
# (10, 2286)
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# simulated_state_at_liftoff_minus
# [-5.67554790e-01  1.31804667e+00  2.97513624e-17 -4.97993252e-01
#   4.98054649e-01 -3.44045525e+00  5.15740555e+00  5.53127734e-16
#  -3.74747422e-01  6.16558145e+00]
# calculated_state_at_liftoff_minus
# [-1.95502179e-04  1.50248662e+00  0.00000000e+00 -1.00130990e-01
#   5.00000000e-01 -3.91001787e-01 -3.92827697e-02  0.00000000e+00
#  -2.61980095e-01  0.00000000e+00]
# simulated_beta
# -0.4979932515779103
# calculated_beta
# -0.10013099004760719
# FAIL
#
# ======================================================================
# FAIL: test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/notebooks/TestTakeOffPlus.py", line 834, in test_liftoff_minus_state_1
#     self.liftoff_minus_state(apex_state, False)
#   File "/notebooks/TestTakeOffPlus.py", line 971, in liftoff_minus_state
#     self.assertAlmostEqual(
# AssertionError: -0.10013099004760719 != -0.4979932515779103 within 1 places (0.39786226153030313 difference)
#
# ----------------------------------------------------------------------
# Ran 1 test in 1.079s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=1 errors=0 failures=1>
