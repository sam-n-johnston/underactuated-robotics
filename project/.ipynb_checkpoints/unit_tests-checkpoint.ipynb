# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
import matplotlib.pyplot as plt
from TestTakeOffPlus import TestTakeOffPlus


suite = unittest.TestLoader().loadTestsFromTestCase(TestTakeOffPlus)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_liftoff_minus_state_0 (TestTakeOffPlus.TestTakeOffPlus) ...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1000">
# ok
# test_liftoff_minus_state_1 (TestTakeOffPlus.TestTakeOffPlus) ...
# testing...
#
# simulated_state_at_liftoff_minus
# [-6.43761747e-06  1.51048893e+00  8.29008800e-19 -4.24751138e-06
#   5.12033671e-01  6.10927670e-04  6.09102998e+00  3.87602277e-18
#   4.35726762e-04  1.85977744e+00]
# calculated_state_at_liftoff_minus
# [0.         1.50203984 0.         0.         0.5        0.
#  6.26299012 0.         0.         0.        ]
# simulated_beta
# -4.247511380165358e-06
# calculated_beta
# 0.0
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1000">
# ok
# test_liftoff_minus_state_2 (TestTakeOffPlus.TestTakeOffPlus) ...
# testing...
#
# simulated_state_at_liftoff_minus
# [-5.67554790e-01  1.31804667e+00 -1.00000000e-01 -3.97993252e-01
#   4.98054649e-01 -3.44045525e+00  5.15740555e+00  2.21957366e-16
#  -3.74747422e-01  6.16558145e+00]
# calculated_state_at_liftoff_minus
# [-0.58502632  1.30933723 -0.1        -0.41106287  0.5        -4.12567974
#   5.36333119  0.          0.          0.        ]
# simulated_beta
# -0.4979932515779343
# calculated_beta
# -0.5110628706464007
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1000">
# ok
# test_liftoff_minus_state_3 (TestTakeOffPlus.TestTakeOffPlus) ...
# testing...
#
# simulated_state_at_liftoff_minus
# [-5.67554790e-01  1.31804667e+00  2.97513624e-17 -4.97993252e-01
#   4.98054649e-01 -3.44045525e+00  5.15740555e+00  5.53127734e-16
#  -3.74747422e-01  6.16558145e+00]
# calculated_state_at_liftoff_minus
# [-0.58502632  1.30933723  0.         -0.51106287  0.5        -4.12567974
#   5.36333119  0.          0.          0.        ]
# simulated_beta
# -0.4979932515779103
# calculated_beta
# -0.5110628706464007
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1000">
# ok
# test_liftoff_minus_state_4 (TestTakeOffPlus.TestTakeOffPlus) ...
# testing...
#
# simulated_state_at_liftoff_minus
# [-5.67554790e-01  1.31804667e+00 -5.00000000e-02 -4.47993252e-01
#   4.98054649e-01 -3.44045525e+00  5.15740555e+00  4.87889032e-16
#  -3.74747422e-01  6.16558145e+00]
# calculated_state_at_liftoff_minus
# [-0.58502632  1.30933723 -0.05       -0.46106287  0.5        -4.12567974
#   5.36333119  0.          0.          0.        ]
# simulated_beta
# -0.497993251577947
# calculated_beta
# -0.5110628706464007
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1000">
# FAIL
# test_liftoff_minus_state_5 (TestTakeOffPlus.TestTakeOffPlus) ...
# testing...
#
# simulated_state_at_liftoff_minus
# [-0.70863681  0.74641871 -0.12311566 -0.93391968  0.49487879 -5.00097927
#   2.17630735  0.42246068 -3.43791695 12.42416559]
# calculated_state_at_liftoff_minus
# [-0.61132514  1.19391629 -0.2        -0.45064505  0.5        -4.35610706
#   4.42741842  0.          0.          0.        ]
# simulated_beta
# -1.0570353402296844
# calculated_beta
# -0.65064504686426
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1000">
# FAIL
# test_liftoff_minus_state_6 (TestTakeOffPlus.TestTakeOffPlus) ...
# testing...
#
# simulated_state_at_liftoff_minus
# [-6.95793786e-01  7.15690196e-01 -4.09435012e-16 -1.08063784e+00
#   4.94636698e-01 -5.00480013e+00  2.00832676e+00 -2.23297310e-16
#  -3.28281569e+00  1.32544555e+01]
# calculated_state_at_liftoff_minus
# [-0.61132514  1.19391629  0.         -0.65064505  0.5        -4.35610706
#   4.42741842  0.          0.          0.        ]
# simulated_beta
# -1.0806378398456467
# calculated_beta
# -0.65064504686426
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1000">
# FAIL
# test_touchdown_minus_state (TestTakeOffPlus.TestTakeOffPlus) ...
# testing...
#
# simulated_state_at_liftoff_minus
# [-6.95793786e-01  7.15690196e-01 -1.00000000e-01 -9.80637840e-01
#   4.94636698e-01 -5.00480013e+00  2.00832676e+00  8.91345970e-16
#  -3.28281569e+00  1.32544555e+01]
# calculated_state_at_liftoff_minus
# [-0.61132514  1.19391629 -0.1        -0.55064505  0.5        -4.35610706
#   4.42741842  0.          0.          0.        ]
# simulated_beta
# -1.080637839845709
# calculated_beta
# -0.65064504686426
# <img src="data:image/png;base64,..." width="640">
# ok
# test_touchdown_minus_state_with_all (TestTakeOffPlus.TestTakeOffPlus) ...
# Simulated vs calculated state at touchdown minus [0]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [1]: 1.51	 VS 	1.50
# Simulated vs calculated state at touchdown minus [2]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [3]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [4]: 0.51	 VS 	0.50
# Simulated vs calculated state at touchdown minus [5]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [6]: -6.24	 VS 	-6.26
# Simulated vs calculated state at touchdown minus [7]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [8]: 0.0	 VS 	0.0
# Simulated vs calculated state at touchdown minus [9]: 0.0	 VS 	0.0
# <img src="data:image/png;base64,..." width="640">
# ok
# test_touchdown_minus_state_with_alpha (TestTakeOffPlus.TestTakeOffPlus) ...
# Simulated vs calculated state at touchdown minus [0]: 0.10	 VS 	0.10
# Simulated vs calculated state at touchdown minus [1]: 1.33	 VS 	1.32
# Simulated vs calculated state at touchdown minus [2]: 0.10	 VS 	0.10
# Simulated vs calculated state at touchdown minus [3]: 0.40	 VS 	0.40
# Simulated vs calculated state at touchdown minus [4]: 0.51	 VS 	0.50
# Simulated vs calculated state at touchdown minus [5]: 0.15	 VS 	0.15
# Simulated vs calculated state at touchdown minus [6]: -6.53	 VS 	-6.55
# Simulated vs calculated state at touchdown minus [7]: -0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [8]: 0.0	 VS 	0.0
# Simulated vs calculated state at touchdown minus [9]: 0.0	 VS 	0.0
# <img src="data:image/png;base64,..." width="640">
# ok
# test_touchdown_minus_state_with_strong_alpha (TestTakeOffPlus.TestTakeOffPlus) ...
# Simulated vs calculated state at touchdown minus [0]: -0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [1]: 1.51	 VS 	1.49
# Simulated vs calculated state at touchdown minus [2]: 0.10	 VS 	0.10
# Simulated vs calculated state at touchdown minus [3]: -0.20	 VS 	-0.20
# Simulated vs calculated state at touchdown minus [4]: 0.51	 VS 	0.50
# Simulated vs calculated state at touchdown minus [5]: -0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [6]: -6.25	 VS 	-6.28
# Simulated vs calculated state at touchdown minus [7]: -0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [8]: -0.0	 VS 	0.0
# Simulated vs calculated state at touchdown minus [9]: 0.0	 VS 	0.0
# <img src="data:image/png;base64,..." width="640">
# ok
# test_touchdown_minus_state_with_theta (TestTakeOffPlus.TestTakeOffPlus) ...
# Simulated vs calculated state at touchdown minus [0]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [1]: 1.39	 VS 	1.38
# Simulated vs calculated state at touchdown minus [2]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [3]: 0.40	 VS 	0.40
# Simulated vs calculated state at touchdown minus [4]: 0.51	 VS 	0.50
# Simulated vs calculated state at touchdown minus [5]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [6]: -6.43	 VS 	-6.45
# Simulated vs calculated state at touchdown minus [7]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [8]: 0.0	 VS 	0.0
# Simulated vs calculated state at touchdown minus [9]: 0.0	 VS 	0.0
# <img src="data:image/png;base64,..." width="640">
# ok
# test_touchdown_minus_state_with_xd (TestTakeOffPlus.TestTakeOffPlus) ...
# Simulated vs calculated state at touchdown minus [0]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [1]: 1.51	 VS 	1.49
# Simulated vs calculated state at touchdown minus [2]: 0.10	 VS 	0.10
# Simulated vs calculated state at touchdown minus [3]: -0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [4]: 0.51	 VS 	0.50
# Simulated vs calculated state at touchdown minus [5]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [6]: -6.25	 VS 	-6.28
# Simulated vs calculated state at touchdown minus [7]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [8]: 0.0	 VS 	0.0
# Simulated vs calculated state at touchdown minus [9]: 0.0	 VS 	0.0
# <img src="data:image/png;base64,..." width="640">
# ok
# test_touchdown_minus_state_with_zd (TestTakeOffPlus.TestTakeOffPlus) ...
# Simulated vs calculated state at touchdown minus [0]: 0.34	 VS 	0.35
# Simulated vs calculated state at touchdown minus [1]: 1.51	 VS 	1.50
# Simulated vs calculated state at touchdown minus [2]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [3]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [4]: 0.51	 VS 	0.50
# Simulated vs calculated state at touchdown minus [5]: 0.50	 VS 	0.50
# Simulated vs calculated state at touchdown minus [6]: -6.26	 VS 	-6.28
# Simulated vs calculated state at touchdown minus [7]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [8]: 0.0	 VS 	0.0
# Simulated vs calculated state at touchdown minus [9]: 0.0	 VS 	0.0
# <img src="data:image/png;base64,..." width="640">
# Simulated vs calculated state at touchdown minus [0]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [1]: 1.51	 VS 	1.50
# Simulated vs calculated state at touchdown minus [2]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [3]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [4]: 0.51	 VS 	0.50
# Simulated vs calculated state at touchdown minus [5]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [6]: -6.26	 VS 	-6.28
# Simulated vs calculated state at touchdown minus [7]: 0.00	 VS 	0.00
# Simulated vs calculated state at touchdown minus [8]: 0.0	 VS 	0.0
# Simulated vs calculated state at touchdown minus [9]: 0.0	 VS 	0.0
# ok
#
# ======================================================================
# FAIL: test_liftoff_minus_state_4 (TestTakeOffPlus.TestTakeOffPlus)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/notebooks/TestTakeOffPlus.py", line 859, in test_liftoff_minus_state_4
#     self.liftoff_minus_state(apex_state)
#   File "/notebooks/TestTakeOffPlus.py", line 927, in liftoff_minus_state
#     self.assertAlmostEqual(
# AssertionError: -0.65064504686426 != -1.0570353402296844 within 1 places (0.4063902933654244 difference)
#
# ======================================================================
# FAIL: test_liftoff_minus_state_5 (TestTakeOffPlus.TestTakeOffPlus)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/notebooks/TestTakeOffPlus.py", line 867, in test_liftoff_minus_state_5
#     self.liftoff_minus_state(apex_state)
#   File "/notebooks/TestTakeOffPlus.py", line 927, in liftoff_minus_state
#     self.assertAlmostEqual(
# AssertionError: -0.65064504686426 != -1.0806378398456467 within 1 places (0.4299927929813867 difference)
#
# ======================================================================
# FAIL: test_liftoff_minus_state_6 (TestTakeOffPlus.TestTakeOffPlus)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/notebooks/TestTakeOffPlus.py", line 876, in test_liftoff_minus_state_6
#     self.liftoff_minus_state(apex_state)
#   File "/notebooks/TestTakeOffPlus.py", line 927, in liftoff_minus_state
#     self.assertAlmostEqual(
# AssertionError: -0.65064504686426 != -1.080637839845709 within 1 places (0.4299927929814491 difference)
#
# ----------------------------------------------------------------------
# Ran 14 tests in 9.471s
#
# FAILED (failures=3)
# <unittest.runner.TextTestResult run=14 errors=0 failures=3>
